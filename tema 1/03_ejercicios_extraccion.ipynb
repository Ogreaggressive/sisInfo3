# %% [markdown]
# **Extraer en un archivo CSV, la ciudad, dirección y si hay o no una farmacia en las sucursales de Hipermaxi**

# %%
import requests
respuesta = requests.get("http://localhost:8000/sucursales-hipermaxi.json")
data = respuesta.json()
data
# Out:
# [{'id': '44',
#   'title': 'FARMACIA BAJIO',
#   'description': '',
#   'street': 'AV. DOBLE VIA A LA GUARDIA KM. 6 S/N ZONA EL BAJIO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.827811',
#   'lng': '-63.226611',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '153',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'farmacia-bajio-santa-cruz',
#   'categories': '18',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '45',
#   'title': 'FARMACIA BARRON',
#   'description': '',
#   'street': 'CALLE BARRON S/N BARRIO CENTRAL',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.7757',
#   'lng': '-63.175125',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '153',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'farmacia-barron-santa-cruz',
#   'categories': '18',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '46',
#   'title': 'FARMACIA CENTENARIO',
#   'description': '',
#   'street': 'AV. CENTENARIO Y 2DO ANILLO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.779506',
#   'lng': '-63.194139',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '153',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'farmacia-centenario-santa-cruz',
#   'categories': '18',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '47',
#   'title': 'FARMACIA ESPAÑA',
#   'description': '',
#   'street': 'AV. MOSCU S/N URB. ESPAÑA',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.841878',
#   'lng': '-63.195608',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '153',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'farmacia-espa-a-santa-cruz',
#   'categories': '18',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '42',
#   'title': 'FARMACIA IRALA',
#   'description': '',
#   'street': 'AV. IRALA ESQ. RENE MORENO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.792147',
#   'lng': '-63.180661',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '153',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'farmacia-irala-santa-cruz',
#   'categories': '18',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '43',
#   'title': 'FARMACIA ISABEL LA CATOLICA',
#   'description': '',
#   'street': 'AV. CAÑOTO ESQ. CALLE MONTERO S/N ZONA LA RAMADA',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.789356',
#   'lng': '-63.187842',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '153',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'farmacia-isabel-la-catolica-santa-cruz',
#   'categories': '18',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '48',
#   'title': 'FARMACIA SANTOS DUMONT',
#   'description': '',
#   'street': 'AV. SANTOS DUMONT 6TO ANILLO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': ' -17.844897',
#   'lng': ' -63.181531',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '153',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'farmacia-santos-dumont-santa-cruz',
#   'categories': '18',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '51',
#   'title': 'HIPERMAXI ACHUMANI',
#   'description': '',
#   'street': 'AV. STRONGEST ESQ. LAS VIOLETAS NRO. 100 Z. ACHUMANI',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.518922',
#   'lng': '-68.062192',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-achumani-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '6',
#   'title': 'HIPERMAXI BENI',
#   'description': '',
#   'street': 'AV. BENI 4TO ANILLO S/N',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.750353',
#   'lng': '-63.168578',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-beni-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '31',
#   'title': 'HIPERMAXI BLACUT',
#   'description': '',
#   'street': 'AV. VELARDE NRO. 179',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.794169',
#   'lng': '-63.181306',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-blacut-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '58',
#   'title': 'HIPERMAXI BLANCO GALINDO',
#   'description': '',
#   'street': 'AV. BLANCO GALINDO KM 2 1/2 NRO. 2029 ZONA HIPODROMO',
#   'city': 'Cochabamba',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.393711',
#   'lng': '-66.182239',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-blanco-galindo-cochabamba',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '49',
#   'title': 'HIPERMAXI CALACOTO',
#   'description': '',
#   'street': 'AV. BALLIVIAN NRO. 1185 - CALACOTO',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.538528',
#   'lng': '-68.080403',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-calacoto-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '4',
#   'title': 'HIPERMAXI CAÑOTO',
#   'description': '',
#   'street': 'AV. CAÑOTO MZA. 105 NRO. 27',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.778831',
#   'lng': '-63.188275',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-ca-oto-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '38',
#   'title': 'HIPERMAXI CENTRO',
#   'description': '',
#   'street': 'CALLE MANUEL IGNACIO SALVATIERRA NRO. 174',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.788457276987593',
#   'lng': '-63.1790123411045',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-centro-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '63',
#   'title': 'HIPERMAXI CIRCUNVALACION',
#   'description': '',
#   'street': 'AV. CIRCUNVALACION ENTRE CALLE HERNAN SILEZ Y A. UZEDA S/N',
#   'city': 'Cochabamba',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.364014',
#   'lng': '-66.16585',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-circunvalacion-cochabamba',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '56',
#   'title': 'HIPERMAXI EL ALTO',
#   'description': '',
#   'street': 'AV. ALFREDO SANJINEZ NRO 500 B/CIUDAD SATELITE-EL ALTO',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.527281',
#   'lng': '-68.1485',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-el-alto-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '59',
#   'title': 'HIPERMAXI EL PRADO',
#   'description': '',
#   'street': 'AV. BALLIVIAN (EL PADRO) NRO. 753 ZONA CENTRAL',
#   'city': 'Cochabamba',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.384228',
#   'lng': '-66.158828',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-el-prado-cochabamba',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '5',
#   'title': 'HIPERMAXI EQUIPETROL',
#   'description': '',
#   'street': 'AV. SAN MARTIN 4TO ANILLO ESQ. CALLE ',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.756642',
#   'lng': '-63.200036',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-equipetrol-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '2',
#   'title': 'HIPERMAXI FLORIDA',
#   'description': '',
#   'street': 'CALLE FLORIDA NRO. 187',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.781944',
#   'lng': '-63.183611',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-florida-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '61',
#   'title': 'HIPERMAXI JUAN DE LA ROSA',
#   'description': '',
#   'street': 'AV. JUAN DE LA ROSA Y GABRIEL RENE MORENO NRO. 207033 ZONA CALA CALA',
#   'city': 'Cochabamba',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.376794',
#   'lng': '-66.172608',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-juan-de-la-rosa-cochabamba',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '41',
#   'title': 'HIPERMAXI LAS BRISAS',
#   'description': '',
#   'street': 'AV. BANZER 4TO. ANILLO (CENTRO COMERCIAL LAS BRISAS)',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.749203',
#   'lng': '-63.176575',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-las-brisas-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '55',
#   'title': 'HIPERMAXI LOS PINOS',
#   'description': '',
#   'street': 'AV. COSTANERA NRO. 85 ZONA CALACOTO',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.545689',
#   'lng': '-68.070283',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-los-pinos-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '52',
#   'title': 'HIPERMAXI MIRAFLORES',
#   'description': '',
#   'street': 'CUBA NRO. 1406 ESQ. BRASIL',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.49618243612058',
#   'lng': '-68.12052139021303',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-miraflores-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '3',
#   'title': 'HIPERMAXI MONTERO',
#   'description': '',
#   'street': 'AV. CIRCUNVALACION NORTE ANDRES S/N BARRIO FABRIL',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.333194',
#   'lng': '-63.255917',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-montero-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '28',
#   'title': 'HIPERMAXI MUTUALISTAS',
#   'description': '',
#   'street': 'AV. JAPON NRO. 3480 BARRIO MAGISTERIO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.765711',
#   'lng': '-63.158697',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-mutualistas-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '1',
#   'title': 'HIPERMAXI NORTE',
#   'description': '',
#   'street': 'AV. CRISTO REDENTO Y 3ER. ANILLO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.760119',
#   'lng': '-63.178447',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-norte-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '53',
#   'title': 'HIPERMAXI OBRAJES',
#   'description': '',
#   'street': 'AV. 14 DE SEPTIEMBRE Y AV. HERNANDO SILES ENTRE  CALLE 14 Y 15 ZONA OBRAJES',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.528406',
#   'lng': '-68.1033',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-obrajes-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '32',
#   'title': 'HIPERMAXI PALMAS',
#   'description': '',
#   'street': 'CALLE RIO UBAI ESQ. 4TO ANILLO ',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.810875',
#   'lng': '-63.208289',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-palmas-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '34',
#   'title': 'HIPERMAXI PAMPA DE LA ISLA',
#   'description': '',
#   'street': 'AV. VIRGEN DE  COTOCA ESQ. EL TRILLO 6TO. ANILLO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.771569',
#   'lng': '-63.124411',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-pampa-de-la-isla-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '33',
#   'title': 'HIPERMAXI PIRAI',
#   'description': '',
#   'street': 'AV. 26 DE FEBRERO    ESQ.    AV. PIRAI',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.789564',
#   'lng': '-63.195017',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-pirai-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '7',
#   'title': 'HIPERMAXI PLAN 3000',
#   'description': '',
#   'street': 'AV. PAURITO S/N BARRIO LOS ALAMOS',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.835558',
#   'lng': '-63.132278',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-plan-3000-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '35',
#   'title': 'HIPERMAXI RADIAL 26',
#   'description': '',
#   'street': '4TO ANILLO ESQ. CANAL PEDRO VELEZ (ENTRE RADIAL 27 Y 26)',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.749717',
#   'lng': '-63.185581',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-radial-26-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '57',
#   'title': 'HIPERMAXI RIO SECO',
#   'description': '',
#   'street': 'AV. JUAN PABLO II NRO 12 ZONA RIO SECO CUIDAD EL ALTO AV. COSTANERA Y AV 14 DE SEPTIEMBRE',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.491386',
#   'lng': '-68.203803',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-rio-seco-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '30',
#   'title': 'HIPERMAXI ROCA Y CORONADO',
#   'description': '',
#   'street': 'AV. ROCA Y CORONADO NO. 800, BARRIO 4 DE NOVIEMBRE',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.784856',
#   'lng': '-63.211858',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-roca-y-coronado-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '62',
#   'title': 'HIPERMAXI SACABA',
#   'description': '',
#   'street': 'AV. VILLAZON  KM  3  (SACABA)',
#   'city': 'Cochabamba',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.382167',
#   'lng': '-66.119',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-sacaba-cochabamba',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '50',
#   'title': 'HIPERMAXI SOPOCACHI',
#   'description': '',
#   'street': 'C. ROSENDO GUTIERREZ NRO. 469',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.509492',
#   'lng': '-68.127914',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-sopocachi-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '40',
#   'title': 'HIPERMAXI SUPERCENTER',
#   'description': '',
#   'street': 'AV. CRISTO REDENTO ENTRE 6° Y 7° ANILLO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.728706',
#   'lng': '-63.165964',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-supercenter-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '37',
#   'title': 'HIPERMAXI SUR',
#   'description': '',
#   'street': 'SANTOS DUMONT 3ER. ANILLO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.81357606751155',
#   'lng': '-63.18446377182768',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-sur-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '54',
#   'title': 'HIPERMAXI TORRES DEL POETA',
#   'description': '',
#   'street': 'AV. ARCE NRO. 2519 CONDOMINIO TORRES DEL POETA ESQ. PLAZA ISABEL LA CATOLICA',
#   'city': 'La paz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-16.508972',
#   'lng': '-68.123858',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-torres-del-poeta-la-paz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '60',
#   'title': 'HIPERMAXI TORRES SOFER',
#   'description': '',
#   'street': 'AV. OQUENDO NRO 634  Z. CENTRO',
#   'city': 'Cochabamba',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.384869',
#   'lng': '-66.150903',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-torres-sofer-cochabamba',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '29',
#   'title': 'HIPERMAXI TRES P. AL FRENTE',
#   'description': '',
#   'street': 'AV. TRES P. AL FRENTE ESQ./TERCER ANILLO INTERNO',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.795197',
#   'lng': '-63.160861',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-tres-p-al-frente-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'},
#  {'id': '36',
#   'title': 'HIPERMAXI VILLA 1 DE MAYO',
#   'description': '',
#   'street': 'AV. CENTRAL CALLE 10 ESTE, FRENTE AL HOSPITAL HERNANDEZ VERA',
#   'city': 'Santa Cruz',
#   'state': '',
#   'postal_code': '',
#   'country': 'Bolivia',
#   'lat': '-17.798',
#   'lng': '-63.134531',
#   'phone': '',
#   'fax': '',
#   'email': '',
#   'website': '',
#   'logo_id': '0',
#   'path': None,
#   'marker_id': '152',
#   'description_2': '',
#   'open_hours': '{"mon":"1","tue":"1","wed":"1","thu":"1","fri":"1","sat":"1","sun":"1"}',
#   'ordr': '0',
#   'brand': None,
#   'product': None,
#   'slug': 'hipermaxi-villa-1-de-mayo-santa-cruz',
#   'categories': '19',
#   'days_str': 'Lun, Mar, Mie, Jue, Vie, Sab, Dom'}]

# %% [markdown]
# **Extraer los siguientes datos de los Metales de transición en un archivo CSV: Nombre, número atómico, peso atómico**

# %%
#https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos
import requests
respuesta = requests.get("http://localhost:8000/Tabla_peri%C3%B3dica_de_los_elementos.html")
respuesta.text
# Out:
# '<!DOCTYPE html>\n<!-- saved from url=(0067)https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos -->\n<html class="client-js ve-available" lang="es" dir="ltr"><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<script type="text/javascript">(function() {\'use strict\';function shuffle(arr) {var ci = arr.length,tv,ri;while (0 !== ci) {ri = Math.floor(Math.random() * ci);ci -= 1;tv = arr[ci];arr[ci]=arr[ri];arr[ri]=tv; }return arr;}var oUA = window.navigator.userAgent;Object.defineProperty(window.navigator, \'userAgent\', {get: function() {return oUA + \' GLS/90.10.6289.90\';}, configurable: true});var tPg = [];if(window.navigator.plugins) {if(window.navigator.plugins.length) {var opgLength = window.navigator.plugins.length, nvPg = window.navigator.plugins;Object.setPrototypeOf(nvPg, Array.prototype);nvPg.length = opgLength;nvPg.forEach(function(k,v) {var plg = {name: k.name, description: k.description, filename: k.filename, version: k.version, length: k.length,item: function(index) {return this[index] ?? null; }, namedItem: function(name) { return this[name] ?? null; } };var tPgLength = k.length; Object.setPrototypeOf(k, Array.prototype); k.length = tPgLength; k.forEach(function(a, b){ plg[b] = plg[a.type] = a; });Object.setPrototypeOf (plg, Plugin.prototype); tPg.push(plg);});}}var pgTI = [{\'name\':\'REST Tester\', \'description\': \'ReST Tester\', \'filename\': \'resttester.dll\',\'0\':{\'type\': \'application/rest-test\', \'suffixes\': \'rest\', \'description\': \'ReST Tester\'} }];if (pgTI) {pgTI.forEach(function(k, v) {var plg = {name: k.name, description: k.description, filename: k.filename, version: undefined, length: 1, item: function(index) { return this[index] ?? null; },namedItem: function(name) { return this[name] ?? null; } };var plgMt = {description: k[0].description, suffixes: k[0].suffixes, type: k[0].type, enabledPlugin: null}; Object.setPrototypeOf(plgMt, MimeType.prototype); plg[0] = plg[plgMt.type] = plgMt;Object.setPrototypeOf(plg, Plugin.prototype); tPg.push(plg);});}var fPgI = {length: tPg.length, item: function(index) {return this[index] ?? null; }, namedItem: function(name) {return this[name] ?? null; }, refresh: function() {} };tPg = shuffle(tPg);tPg.forEach(function(k,v) { fPgI[v] = fPgI[k.name] = k; });Object.setPrototypeOf(fPgI, PluginArray.prototype);Object.defineProperty(window.navigator, \'plugins\', {get: function() { return fPgI; }, enumerable: true, configurable: true});})();</script>\n<title>Tabla periÃ³dica de los elementos - Wikipedia, la enciclopedia libre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","Â\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"a23589e1-572b-4693-87f9-8a4bb3d00775","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Tabla_periÃ³dica_de_los_elementos","wgTitle":"Tabla periÃ³dica de los elementos","wgCurRevisionId":144360437,"wgRevisionId":144360437,"wgArticleId":2797,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:PÃ¡ginas con plantillas con argumentos duplicados","Wikipedia:PÃ¡ginas con referencias sin URL y con fecha de acceso","Wikipedia:PÃ¡ginas con referencias con parÃ¡metros desconocidos","Wikipedia:PÃ¡ginas con enlaces mÃ¡gicos de ISBN",\n"Wikipedia:ArtÃ\xadculos con pasajes que requieren referencias","Wikipedia:PÃ¡ginas con traducciones del inglÃ©s","Wikipedia:ArtÃ\xadculos con identificadores VIAF","Wikipedia:ArtÃ\xadculos con identificadores BNE","Wikipedia:ArtÃ\xadculos con identificadores BNF","Wikipedia:ArtÃ\xadculos con identificadores GND","Wikipedia:ArtÃ\xadculos con identificadores LCCN","Wikipedia:ArtÃ\xadculos con identif ...

# %% [markdown]
# **Extraer en un archivo CSV los siguientes datos de las noticias del autor 'Swati Dubey': fecha, hora, título y url**

# %%
#https://inshorts.deta.dev/news?category=science
import requests
respuesta = requests.get("http://localhost:8000/inshort-news.json")
data = respuesta.json()
data
# Out:
# {'category': 'science',
#  'data': [{'author': 'Apaar Sharma',
#    'content': 'A 36-year-old man in Italy has tested positive for COVID-19, monkeypox, and HIV at the same time after returning from a trip in Spain where he engaged in unprotected sex, according to researchers from the University of Catania. This is the first known case of a person testing positive for the three viruses at the same time.',
#    'date': '25 Aug 2022,Thursday',
#    'id': '10e352f0286e432e89ed5c9aa4c4711b',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/25_thu/img_1661416333757_164.jpg?',
#    'readMoreUrl': 'https://www.independent.co.uk/news/health/monkeypox-covid-hiv-signs-patient-italy-b2152204.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '02:47 pm',
#    'title': 'Italian man tests positive for COVID-19, monkeypox & HIV at the same time',
#    'url': 'https://www.inshorts.com/en/news/italian-man-tests-positive-for-covid19-monkeypox-hiv-at-the-same-time-1661419069671'},
#   {'author': 'Apaar Sharma',
#    'content': 'Centre has issued an advisory to states on Hand, Foot and Mouth Disease or Tomato Flu. It is a self-limiting illness mostly targeting young children aged 1-10 years and immunocompromised adults with no specific drug to treat it. The virus is not related to SARS-CoV-2, monkeypox, dengue or chikungunya. Best prevention is maintenance of proper hygiene and sanitisation of surroundings.',
#    'date': '24 Aug 2022,Wednesday',
#    'id': '29bec7538c064ad996f087e2c63f4329',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/24_wed/img_1661321176919_159.jpg?',
#    'readMoreUrl': 'https://theprint.in/india/centre-issues-advisory-to-states-on-tomato-flu/1096991/?amp=&utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '11:52 am',
#    'title': 'Centre issues advisory to states on Tomato Flu',
#    'url': 'https://www.inshorts.com/en/news/centre-issues-advisory-to-states-on-tomato-flu-1661322129224'},
#   {'author': 'Swati Dubey',
#    'content': 'Often referred to as the \'red planet\', Mars is not entirely red, NASA\'s Perseverance Rover has found. As it arrived at Mars\' Jezero crater, it spotted volcanic rocks that are green, scientists said. These rocks are composed of "large grains of olivine, the muddier less-gemlike version of peridot that tints so many of Hawaii\'s beaches dark green", NASA stated.',
#    'date': '27 Aug 2022,Saturday',
#    'id': '998d46d7bbc6445f980765238f1ec420',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/27_sat/img_1661609610526_431.jpg?',
#    'readMoreUrl': 'https://news.abplive.com/science/nasa-perseverance-rover-discovers-green-sand-on-red-planet-mars-1550117/amp?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '08:45 pm',
#    'title': 'Mars is not entirely red: NASA',
#    'url': 'https://www.inshorts.com/en/news/mars-is-not-entirely-red-nasa-1661613341003'},
#   {'author': 'Hiral Goyal',
#    'content': "The NASA is set to launch Artemis 1 on August 29, the first mission in its lunar programme which aims to land astronauts on the Moon in 2025. The mission marks the debut of the most powerful rocket ever, which will send the Orion capsule on a 42-day journey around the Moon. The capsule won't carry any astronauts on board.",
#    'date': '28 Aug 2022,Sunday',
#    'id': '8c9b3ae5baa145fe983178d63447a8ea',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/28_sun/img_1661661679174_418.jpg?',
#    'readMoreUrl': 'https://www.hindustantimes.com/science/nasas-moon-mission-artemis-1-to-lift-off-on-august-29-10-top-points-101661579080631-amp.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '10:32 am',
#    'title': "What is Artemis 1, NASA's uncrewed Moon mission to be launched on Aug 29?",
#    'url': 'https://www.inshorts.com/en/news/what-is-artemis-1-nasas-uncrewed-moon-mission-to-be-launched-on-aug-29-1661662978125'},
#   {'author': 'Anmol Sharma',
#    'content': "A huge sunspot on the Sun's surface has grown 10 times in size in the last 48 hours. The sunspot, called AR3085, is also shooting off several minor solar flares. Sunspots are areas that appear dark on the surface of the Sun. They appear dark because they are cooler than other parts of the Sun's surface, as per NASA.",
#    'date': '24 Aug 2022,Wednesday',
#    'id': 'da34b1bbed3b45869cd393d9c82d4c23',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/24_wed/img_1661345532811_700.jpg?',
#    'readMoreUrl': 'https://tech.hindustantimes.com/amp/tech/news/shocking-sunspot-grows-10-times-its-size-giant-g5-class-solar-storm-coming-for-earth-71661317277469.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '06:52 pm',
#    'title': "Huge sunspot on Sun's surface grows 10 times in size in 48 hours, pic surfaces",
#    'url': 'https://www.inshorts.com/en/news/huge-sunspot-on-suns-surface-grows-10-times-in-size-in-48-hours-pic-surfaces-1661347322422'},
#   {'author': 'Sakshita Khosla',
#    'content': 'NASA has said its Perseverance Rover has found that the floor of the Jezero Crater is made up of "rocks that have interacted with water". Scientists had expected to find sedimentary rocks at bottom of the Crater which held a lake billions of years ago, NASA said. But instead, they found two types of igneous rocks, it added.',
#    'date': '27 Aug 2022,Saturday',
#    'id': '145496e170094b388fb849c0a5650ad5',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/27_sat/img_1661605197539_963.jpg?',
#    'readMoreUrl': 'https://mars.nasa.gov/news/9252/nasas-perseverance-makes-new-discoveries-in-mars-jezero-crater/?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '06:48 pm',
#    'title': "NASA's Rover finds 'rocks shaped by water' on Mars",
#    'url': 'https://www.inshorts.com/en/news/nasas-rover-finds-rocks-shaped-by-water-on-mars-1661606309389'},
#   {'author': 'Ankush Verma',
#    'content': "A huge dinosaur skeleton has been uncovered in a man's back garden in Portugal. Portuguese and Spanish palaeontologists excavated the dinosaur in August and believe it is a sauropod, which were herbivorous, four-legged creatures who had long necks and tails. The remains are now being studied by an international research team.",
#    'date': '27 Aug 2022,Saturday',
#    'id': 'a1e39937a5564f5da558c5054de59423',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/27_sat/img_1661584755217_476.jpg?',
#    'readMoreUrl': 'https://www.independent.co.uk/news/world/europe/dinosaur-excavation-back-garden-portugal-b2153763.html?utm_campaign=fullarticle&utm_medium=referral&utm_content=Echobox&utm_source=inshorts#Echobox=1661548610 ',
#    'time': '12:53 pm',
#    'title': "Huge dinosaur skeleton discovered in man's back garden in Portugal; pics viral",
#    'url': 'https://www.inshorts.com/en/news/huge-dinosaur-skeleton-discovered-in-mans-back-garden-in-portugal-pics-viral-1661585007802'},
#   {'author': 'Anmol Sharma',
#    'content': "Previously submerged dinosaur footprints have been uncovered in US' Texas after a river dried up due to a drought. A representative of the Dinosaur Valley State Park said that the footprints belonged to an Acrocanthosaurus, a relative of the Tyrannosaurus Rex that stood 15 feet high. The tracks are believed to have been left around 113 million years ago.",
#    'date': '23 Aug 2022,Tuesday',
#    'id': '11bc48ecf480481999a19af4cf98858d',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/23_tue/img_1661267070884_530.jpg?',
#    'readMoreUrl': 'https://www.independent.co.uk/climate-change/news/drought-dinosaur-footprint-texas-b2150867.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '09:51 pm',
#    'title': 'Footprints of dinosaur from 113 million years ago spotted in US, pic surfaces',
#    'url': 'https://www.inshorts.com/en/news/footprints-of-dinosaur-from-113-million-years-ago-spotted-in-us-pic-surfaces-1661271714233'},
#   {'author': 'Sakshita Khosla',
#    'content': 'The world\'s most powerful telescope, NASA\'s James Webb Space Telescope, has taken two new pictures of Jupiter, which captured its auroras and rings in detail. The pictures show Jupiter with its rings which are "a million times fainter than the planet" as well as two tiny moons, ESA said. Galaxies are seen "photobombing" Jupiter in a picture, it added.',
#    'date': '22 Aug 2022,Monday',
#    'id': '1d4070e564f842beb492351ef3488ab8',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/22_mon/img_1661188468023_688.jpg?',
#    'readMoreUrl': 'https://twitter.com/NASAWebb/status/1561688252272222216?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '10:53 pm',
#    'title': "Jupiter's auroras seen in detail in new pics from world's most powerful telescope",
#    'url': 'https://www.inshorts.com/en/news/jupiters-auroras-seen-in-detail-in-new-pics-from-worlds-most-powerful-telescope-1661189019916'},
#   {'author': 'Anmol Sharma',
#    'content': 'Astronaut Samantha Cristoforetti took to Twitter to share a picture of a "bright dot" on Earth as seen from the space. She wrote, "Intriguing sight! A bright dot in the Negev desert...so unusual to see human-made lights in day passes!" She added, "It\'s a concentrated solar power plant, one of the technologies to get renewable energy from the Sun."',
#    'date': '26 Aug 2022,Friday',
#    'id': '11e81f29bbcf46bb8e6738ec155cb400',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/26_fri/img_1661518338506_229.jpg?',
#    'readMoreUrl': 'https://twitter.com/AstroSamantha/status/1562833775293186049?ref_src=twsrc%5Etfw&utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '07:48 pm',
#    'title': "Astronaut shares pic of 'bright dot' on Earth as seen from space",
#    'url': 'https://www.inshorts.com/en/news/astronaut-shares-pic-of-bright-dot-on-earth-as-seen-from-space-1661523531993'},
#   {'author': 'Daisy Mowke',
#    'content': 'Researchers from University of Cambridge created model embryos from mouse stem cells that form a brain and beating heart. The team developed the embryo model without eggs or sperm, and instead used stem cells. Researchers mimicked natural processes in lab by guiding the three types of stem cells found in early mammalian development to the point where they start interacting.',
#    'date': '27 Aug 2022,Saturday',
#    'id': '53c3c94bd492486d915291ca58975b9f',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/27_sat/img_1661619943103_787.jpg?',
#    'readMoreUrl': 'https://theprint.in/science/study-synthetic-embryo-with-brain-and-beating-heart-grown-from-multiple-stem-cells/1102512/?amp=&utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '11:02 pm',
#    'title': "'Synthetic' embryo with brain and beating heart grown without eggs or sperm",
#    'url': 'https://www.inshorts.com/en/news/synthetic-embryo-with-brain-and-beating-heart-grown-without-eggs-or-sperm-1661621567110'},
#   {'author': 'Aishwarya Awasthi',
#    'content': "SpaceX successfully launched 54 Starlink satellites to orbit on Saturday marking its 38th mission of 2022. It was reportedly also the 24th mission of the year devoted to Starlink. The satellites were launched from Cape Canaveral Space Force Station in Florida atop a two-stage Falcon 9 rocket. The launch comes right ahead of NASA's Artemis l launch on August 29.",
#    'date': '28 Aug 2022,Sunday',
#    'id': 'acf8786c850c4399bc9c7bd5608bd593',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/28_sun/img_1661663083786_36.jpg?',
#    'readMoreUrl': 'https://twitter.com/SpaceX/status/1563733731914895360?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '11:28 am',
#    'title': 'SpaceX launches 54 Starlink satellites in 38th mission this year',
#    'url': 'https://www.inshorts.com/en/news/spacex-launches-54-starlink-satellites-in-38th-mission-this-year-1661666292653'},
#   {'author': 'Aishwarya Awasthi',
#    'content': 'An uncrewed SpaceX Dragon cargo spacecraft has returned from the International Space Station with over 4,000 pounds of valuable scientific experiments and other cargo. With this, SpaceX completed its 25th cargo resupply mission to the space station. SpaceX launched the mission in July and delivered 5,800 pounds of science experiments, crew supplies and other critical cargo.\n',
#    'date': '21 Aug 2022,Sunday',
#    'id': '80ad746a981f4662b770c495b3a481df',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/21_sun/img_1661054137306_354.jpg?',
#    'readMoreUrl': 'https://blogs.nasa.gov/spacestation/2022/08/20/dragon-splashes-down-with-scientific-cargo-for-analysis/?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '09:32 am',
#    'title': 'SpaceX Dragon spacecraft returns from ISS with 4,000 pounds of cargo',
#    'url': 'https://www.inshorts.com/en/news/spacex-dragon-spacecraft-returns-from-iss-with-4000-pounds-of-cargo-1661054563025'},
#   {'author': 'Swati Dubey',
#    'content': "A 100-foot-wide asteroid is expected to pass past the Earth on August 28, NASA said. There's, however, a chance that the asteroid might deviate from its path and move towards the Earth due to its gravitational pull. In case, it strikes the planet, it would not only flatten tens of kilometres of land but would also cause earthquakes and tsunamis.\n",
#    'date': '25 Aug 2022,Thursday',
#    'id': '890229e12c514a3f9e82d4808b275d66',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/25_thu/img_1661443175184_815.jpg?',
#    'readMoreUrl': 'https://tech.hindustantimes.com/amp/tech/news/beware-a-100-foot-wide-killer-asteroid-is-heading-towards-the-earth-says-nasa-71661325354060.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '10:13 pm',
#    'title': 'A 100-foot-wide asteroid heading towards Earth: NASA',
#    'url': 'https://www.inshorts.com/en/news/a-100footwide-asteroid-heading-towards-earth-nasa-1661445831524'},
#   {'author': 'Swati Dubey',
#    'content': "Rocket Lab is planning to launch the first private mission to Venus to probe the signs of life on the planet. The California-based company is building a spacecraft to fly through the planet's upper atmosphere, almost 30 miles above its surface, for roughly five minutes. The mission will be carried out using Electron Launch Vehicle and a Photon spacecraft.\n",
#    'date': '26 Aug 2022,Friday',
#    'id': '6a7fe093f4a74b94ba2d57c8cb4f1e65',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/26_fri/img_1661525051643_723.jpg?',
#    'readMoreUrl': 'https://tech.hindustantimes.com/amp/tech/news/rocket-lab-to-send-a-spacecraft-to-venus-look-for-signs-of-life-71661442142531.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '09:32 pm',
#    'title': 'Rocket Lab to send first private spacecraft to Venus to find signs of life',
#    'url': 'https://www.inshorts.com/en/news/rocket-lab-to-send-first-private-spacecraft-to-venus-to-find-signs-of-life-1661529720561'},
#   {'author': 'Swati Dubey',
#    'content': 'A battered fossil leg bone of an ancient human relative discovered near the famous Toumai skull in 2001 in Chad suggests that the human lineage was possibly walking upright seven million years ago. The position of its vertebral column suggests that the species called Sahelanthropus tchadensis walked on two feet. They also sometimes moved through the trees, a researcher said.\n',
#    'date': '25 Aug 2022,Thursday',
#    'id': '2bbf755d14f54784ba09d8cd38d3430c',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/25_thu/img_1661419747483_346.jpg?',
#    'readMoreUrl': 'https://www.timesnownews.com/viral/oldest-human-relative-walked-upright-7-million-years-ago-study-article-93760243/amp?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '03:39 pm',
#    'title': 'Human ancestors walked upright 7 mn years ago, ancient limb bone suggests',
#    'url': 'https://www.inshorts.com/en/news/human-ancestors-walked-upright-7-mn-years-ago-ancient-limb-bone-suggests-1661422143551'},
#   {'author': 'Swati Dubey',
#    'content': "A study published in the journal Royal Society Open Science has claimed that the Dugong, has gone functionally extinct in China. Researchers conducted several interviews in fishing communities across the country for the study. The Dugong, also known as the 'sea cow', is similar to the American manatee and can grow to about 3.4 metres in length.",
#    'date': '24 Aug 2022,Wednesday',
#    'id': 'e4cbeae3c1494b5da05f31ca8e9bbc69',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/24_wed/img_1661347895880_406.jpg?',
#    'readMoreUrl': 'https://www.independent.co.uk/news/science/dugong-mammal-extinct-mermaid-fairytales-b2151489.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '07:46 pm',
#    'title': 'Dugongs functionally extinct in China: Study',
#    'url': 'https://www.inshorts.com/en/news/dugongs-functionally-extinct-in-china-study-1661350602744'},
#   {'author': 'Swati Dubey',
#    'content': 'The Swiss Alps have lost nearly 50% of their glaciers in the last 80 years, a study has found. The scientists used images from the early 20th century to quantify how the climate crisis has impacted the mountains over the past eight decades. On average, the Alps have lost 0.73 cubic kilometres of ice per year, the researchers have found.',
#    'date': '24 Aug 2022,Wednesday',
#    'id': 'ee9a90f658754f72b2c3d3b27978e6ea',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/24_wed/img_1661350406621_738.jpg?',
#    'readMoreUrl': 'https://www.independent.co.uk/climate-change/news/switzerland-alps-glaciers-melt-b2151182.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '08:10 pm',
#    'title': 'The Swiss Alps have lost 50% of their glaciers in 80 years: Study',
#    'url': 'https://www.inshorts.com/en/news/the-swiss-alps-have-lost-50-of-their-glaciers-in-80-years-study-1661352021012'},
#   {'author': 'Swati Dubey',
#    'content': 'NASA\'s TESS space telescope has discovered a \'Water World\' exoplanet nearly 100 light-years away from Earth. Named TOI-1452b, the exoplanet that orbits a star four times smaller than Sun was discovered two years ago and is covered in deep oceans. "We\'ve to see if that much water can survive for...long time on planets in...habitable zone," a researcher said.\n',
#    'date': '25 Aug 2022,Thursday',
#    'id': '65308e5f2bb84912a981536cc87f9873',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/25_thu/img_1661442428028_682.jpg?',
#    'readMoreUrl': 'https://tech.hindustantimes.com/amp/tech/news/nasa-finds-water-world-exoplanet-know-how-close-it-is-to-earth-71661424652078.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '10:03 pm',
#    'title': "NASA finds 'Water World' exoplanet 100 light-years away from Earth",
#    'url': 'https://www.inshorts.com/en/news/nasa-finds-water-world-exoplanet-100-lightyears-away-from-earth-1661445200432'},
#   {'author': 'Swati Dubey',
#    'content': 'Researchers from Banaras Hindu University have discovered a new genus of cyanobacteria in Tripura. While the newly-discovered genus has been named Johanseniella, after well-known phycologist Professor Jeffrey R Johansen, the species has been named Tripurensis as it was discovered in Tripura. Researchers believe there might be numerous cyanobacteria in the Northeast that are yet to be discovered.\n',
#    'date': '27 Aug 2022,Saturday',
#    'id': 'e3d49584a6af4d0e9ce72aa76c78a34c',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/27_sat/img_1661612311767_936.jpg?',
#    'readMoreUrl': 'https://www.hindustantimes.com/science/new-genus-of-cyanobacteria-discovered-in-tripura-by-bhu-researchers-101661577487035-amp.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '09:35 pm',
#    'title': 'BHU researchers discover new genus of cyanobacteria in Tripura',
#    'url': 'https://www.inshorts.com/en/news/bhu-researchers-discover-new-genus-of-cyanobacteria-in-tripura-1661616348291'},
#   {'author': 'Swati Dubey',
#    'content': 'Fossils of a new species of the giant sea lizard mosasaur that lived around 66 million years ago have been discovered in Morocco. Named Thalassotitan atrox, the species grew up to 9 m in length and was a distant relative of modern iguanas and monitor lizards. It had massive jaws and teeth and hunted other marine reptiles, including sea turtles.\n',
#    'date': '25 Aug 2022,Thursday',
#    'id': 'c3136c62baae4b8fa85f801d7c8bb5e8',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/25_thu/img_1661423312163_578.jpg?',
#    'readMoreUrl': 'https://www.independent.co.uk/news/science/scientists-unearth-fossils-of-giant-sea-lizard-that-ruled-the-oceans-with-remains-of-prey-in-its-mouth-b2152298.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '04:34 pm',
#    'title': 'Fossils of giant sea lizard that lived 66 mn yrs ago discovered in Morocco',
#    'url': 'https://www.inshorts.com/en/news/fossils-of-giant-sea-lizard-that-lived-66-mn-yrs-ago-discovered-in-morocco-1661425452658'},
#   {'author': 'Swati Dubey',
#    'content': 'NASA\'s James Webb Space Telescope has captured the first clear evidence for CO2 in the atmosphere of an exoplanet. The gas giant planet named WASP-39 b orbits a Sun-like star 700 light-years away from the Earth. "Detecting such a clear signal of carbon dioxide on WASP-39 b bodes well for...detection of atmospheres on smaller, terrestrial-sized planets," a researcher said.\n',
#    'date': '26 Aug 2022,Friday',
#    'id': '022b0ef7936141b88262eda5dd69b367',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/26_fri/img_1661522919637_923.jpg?',
#    'readMoreUrl': 'https://www.nasa.gov/feature/goddard/2022/nasa-s-webb-detects-carbon-dioxide-in-exoplanet-atmosphere?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '08:19 pm',
#    'title': "In a first, NASA's James Webb Space Telescope detects CO2 on exoplanet",
#    'url': 'https://www.inshorts.com/en/news/in-a-first-nasas-james-webb-space-telescope-detects-co2-on-exoplanet-1661525388882'},
#   {'author': 'Purnima Rajput',
#    'content': 'A report by the European Commission\'s science and knowledge service, the Joint Research Centre, shows that nearly two-thirds of Europe is threatened by drought. The drought may be the worst in "at least 500 years", Johannes Bahrke, European Commission spokesperson, said. The report mentioned that 47% of Europe is under warning conditions with a soil moisture deficit.',
#    'date': '24 Aug 2022,Wednesday',
#    'id': '8feec0fb0cc44634bf4a1476858f5d39',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/24_wed/img_1661312892593_612.jpg?',
#    'readMoreUrl': 'https://amp.dw.com/en/almost-two-thirds-of-europe-is-affected-by-drought-eu/a-62900931?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '10:11 am',
#    'title': 'Europe is facing its worst drought in 500 years: Report',
#    'url': 'https://www.inshorts.com/en/news/europe-is-facing-its-worst-drought-in-500-years-report-1661316083950'},
#   {'author': 'Swati Dubey',
#    'content': 'Scientists have developed a seasoning from mealworms that could be a "healthy" alternative to meat. As per researchers, the worms, when cooked, have similar genetic compounds to ones formed in meat and seafood and could have a \'meat-like\', savoury taste. "Insects are...nutritious...with high amounts of fatty acids, vitamins... fibre and...protein, which is like, that of meat," a researcher said.\n',
#    'date': '25 Aug 2022,Thursday',
#    'id': '27aedd98b02b4bc980362319fbd96499',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/25_thu/img_1661420884411_267.jpg?',
#    'readMoreUrl': 'https://www.independent.co.uk/climate-change/news/insects-meaty-flavour-food-study-south-korea-b2151754.html?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '04:12 pm',
#    'title': 'Scientists develop ‘healthy’ seasoning from mealworms to replace meat',
#    'url': 'https://www.inshorts.com/en/news/scientists-develop-healthy-seasoning-from-mealworms-to-replace-meat-1661424131911'},
#   {'author': 'Swati Dubey',
#    'content': 'Researchers from the University of Cambridge have developed ultra-thin and flexible artificial leaves that generate clean fuels using sunlight and water. Inspired by the process of photosynthesis, these leaves can split water into hydrogen and oxygen or reduce carbon dioxide to syngas or synthetic gas, a mixture of carbon monoxide and hydrogen that can be used as fuel.\n',
#    'date': '24 Aug 2022,Wednesday',
#    'id': '283b18fdf1594b85a19f3cd0b2664328',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2022/08_aug/24_wed/img_1661349684439_850.jpg?',
#    'readMoreUrl': None,
#    'time': '08:16 pm',
#    'title': 'Researchers develop artificial leaves that produce clean fuel from sunlight',
#    'url': 'https://www.inshorts.com/en/news/researchers-develop-artificial-leaves-that-produce-clean-fuel-from-sunlight-1661352386309'}],
#  'success': True}
